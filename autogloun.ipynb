# %%
# !pip install ray==2.10.0
# !pip install autogluon.tabular
# !pip install -U ipywidgets

# %%
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
train_df = pd.read_csv('data/playground-series-s4e8/train.csv').drop('id', axis=1)
train_df.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     e          8.80         f           s         u                    f
# 1     p          4.51         x           h         o                    f
# 2     e          6.94         f           s         b                    f
# 3     e          3.88         f           y         g                    f
# 4     e          5.85         x           l         w                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               a            c          w         4.51  ...        NaN
# 1               a            c          n         4.79  ...        NaN
# 2               x            c          w         6.85  ...        NaN
# 3               s          NaN          g         4.16  ...        NaN
# 4               d          NaN          w         3.37  ...        NaN
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
test_df = pd.read_csv('data/playground-series-s4e8/test.csv').drop('id', axis=1)
test_df.head()
# Out:
#    cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0          8.64         x         NaN         n                    t
# 1          6.90         o           t         o                    f
# 2          2.00         b           g         n                    f
# 3          3.47         x           t         n                    f
# 4          6.17         x           h         y                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width stem-root  \
# 0             NaN          NaN          w        11.13       17.12         b
# 1             NaN            c          y         1.27       10.75       NaN
# 2             NaN            c          n         6.18        3.14       NaN
# 3               s            c          n         4.98        8.51       NaN
# 4               p          NaN          y         6.73       13.70       NaN
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
predictor = TabularPredictor(label='class',
                            eval_metric='mcc',
                            problem_type='binary').fit(train_df,
                                                       presets='best_quality',
                                                        # time_limit=3600*10,
                                                        time_limit=3600*1,
                                                       verbosity=2,
                                                       excluded_model_types=['KNN'],
                                                      #  ag_args_fit={'num_gpus': 1}
                                                      )
results = predictor.fit_summary()
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240829_104610"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #40~22.04.3-Ubuntu SMP PREEMPT_DYNAMIC Tue Jul 30 17:30:19 UTC 2
# CPU Count:          20
# Memory Avail:       4.54 GB / 31.14 GB (14.6%)
# Disk Space Avail:   262.10 GB / 575.18 GB (45.6%)
# ...
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# ...

# %%
predictor.leaderboard()
# Out:
#                  model  score_val eval_metric  pred_time_val    fit_time  \
# 0  WeightedEnsemble_L3   0.984599         mcc     376.998131  735.594141
# 1    LightGBMXT_BAG_L1   0.984559         mcc     288.334444  427.465451
# 2  WeightedEnsemble_L2   0.984559         mcc     288.972983  436.830304
# 3    LightGBMXT_BAG_L2   0.984345         mcc     374.834343  689.788239
# 4      LightGBM_BAG_L2   0.984227         mcc     304.315593  509.443925
# 5      LightGBM_BAG_L1   0.977344         mcc      14.441988   54.541655
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.624627          18.369084            3       True
# 1              288.334444         427.465451            1       True
# 2                0.638538           9.364853            2       True
# 3               72.057911         207.781133            2       True
# 4                1.539160          27.436819            2       True
# ...

# %%
y_pred = predictor.predict(test_df)

# %%
sub = pd.read_csv('data/playground-series-s4e8/sample_submission.csv')
sub['class'] = y_pred
sub.to_csv('submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sub = pd.read_csv('data/playground-series-s4e8/sample_submission.csv')
#       2 sub['class'] = y_pred
#       3 sub.to_csv('submission.csv', index=False)
#
# NameError: name 'pd' is not defined
